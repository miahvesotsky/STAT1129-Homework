# %%
matrixa = matrix(c(7, 2, 9, 4, 12, 13), nrow = 2, ncol = 3)
matrixa
# Out:
#      [,1] [,2] [,3]
# [1,] 7    9    12
# [2,] 2    4    13

# %%
matrixb = matrix(c(1, 2, 3, 7, 8, 9, 12, 13, 14, 19, 20, 21), nrow = 3, ncol = 4)
matrixb
# Out:
#      [,1] [,2] [,3] [,4]
# [1,] 1    7    12   19
# [2,] 2    8    13   20
# [3,] 3    9    14   21

# %%
matrix = matrixa %*% matrixb
matrix
# Out:
#      [,1] [,2] [,3] [,4]
# [1,] 61   229  369  565
# [2,] 49   163  258  391

# %%
table1 = data.frame (
    id = c(1, 2, 3, 4, 5),
    name = c("Peter", "Amy", "Ryan", "Gary", "Michelle"),
    salary = c(623.30, 515.20, 611.00, 729.00, 843.25)
)
table1
# Out:
#   id name     salary
# 1 1  Peter    623.30
# 2 2  Amy      515.20
# 3 3  Ryan     611.00
# 4 4  Gary     729.00
# 5 5  Michelle 843.25

# %%
table2 = cbind(table1, department = c("IT", "finance", "computer science", "sales", "research"))
table2
# Out:
#   id name     salary department
# 1 1  Peter    623.30 IT
# 2 2  Amy      515.20 finance
# 3 3  Ryan     611.00 computer science
# 4 4  Gary     729.00 sales
# 5 5  Michelle 843.25 research

# %%
extract = table2[c(1, 3, 5), c(2, 3)]
extract
# Out:
#   name     salary
# 1 Peter    623.30
# 3 Ryan     611.00
# 5 Michelle 843.25

# %%
x = c("Peter", "Gary", "Michelle")
y = c(623.30, 729, 843.25)

barplot(y, names.arg = x)
# Out:
# plot without title

# %%
x <- c(843.25,515.20,623.30)
labels = c("Highest Salary", "Lowest Salary", "Median Salary")

pie(x, labels, main = "Salaries")
# Out:
# Plot with title “Salaries”
